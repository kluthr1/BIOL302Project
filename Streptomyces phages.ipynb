# %%
import requests

# %%
#STEP 1 
#GENERATE A LIST OF ALL STREPTOMYCES SPECIES

response = requests.get("https://phagesdb.org/api/host_species/")

all_species = []
for x in response.json():
    if x["genus"] == 'Streptomyces':
        all_species.append(x["id"])
        print(x["genus"] + " "+ x["species_name"] )
# Out:
# Streptomyces antibioticus
# Streptomyces aureofaciens
# Streptomyces avermitilis
# Streptomyces azureus
# Streptomyces bicolor
# Streptomyces cattleya
# Streptomyces coelicolor
# Streptomyces flavogriseus
# Streptomyces flavovirens
# Streptomyces griseofuscus
# Streptomyces griseus
# Streptomyces himastatinicus
# Streptomyces indigocolor
# Streptomyces lividans
# Streptomyces mirabilis
# Streptomyces platensis
# Streptomyces roseosporus
# Streptomyces sanglieri
# Streptomyces scabiei
# Streptomyces sp.
# Streptomyces toxytricini
# Streptomyces tricolor
# Streptomyces venezuelae
# Streptomyces virginiae
# Streptomyces viridochromogenes
# Streptomyces xanthochromogenes

# %%
#STEP 2: Now that we found all the host, can we find the siphoviridae phages infecting these host

all_phages = []
for x in all_species:
    response = requests.get("https://phagesdb.org/api/host_species/" + str(x)+ "/phagelist/")
    for x in response.json()["results"]:
        if (x['morphotype']) == 'SIPHO':
            all_phages.append(x)

# %%
len(all_phages)
c = 0
valid_phages = []
for x in all_phages:
    if (x["em_file"]) != None and x["genome_length"] != None:
        valid_phages.append(x)
        c = c+1
print(c)
# Out:
# 103

# %%
all_phages[1]
# Out:
# {'phage_name': 'Rowa',
#  'old_names': '',
#  'program': {'short_name': 'SEAPHAGES',
#   'program_name': 'Science Education Alliance-Phage Hunters Advancing Genomics and Evolutionary Science',
#   'program_blurb': '',
#   'program_URL': 'http://www.hhmi.org/grants/sea/index.html'},
#  'naming_notes': "It's  a girl name in Arabic. It gives the meaning of saturation.I like this name and it might be the name of my daughter in future",
#  'finder_name': 'Ahmad Sulaiman',
#  'found_city': 'New Braunfels',
#  'found_state': 'TX',
#  'found_country': 'USA',
#  'found_GPS_lat': '29.711028 N',
#  'found_GPS_long': '98.133833 W',
#  'found_year': 2016,
#  'p_institution': {'institution_code': 'UNTD',
#   'institution_name': 'University of North Texas',
#   'institution_logo': 'https://phagesdb.org/media/institutions/UNT-01.jpg',
#   'institution_url': 'http://www.unt.edu/'},
#  'enriched_sample': True,
#  'discovery_notes': 'The soil sample was collected from Landa Park in New Braunfels, TX. The temperatures was 24°C, and the soil was wet. The sample was taken 2 cm under surface.',
#  'isolation_temperature': 24,
#  'growth_notes': '',
#  'pcluster': {'cluster': 'BL', 'temperate': True},
#  'psubcluster': None,
#  'morphotype': 'SIPHO',
#  'plaque_notes': 'the diameter is 0.5 mm. It makes cloudy zone in the spot test.',
#  'lysogeny_notes': '',
#  'seq_finished': True,
#  'date_finished': '2017-03-06',
#  'seq_facility': {'short_name': 'UNT',
#   'facility_name': 'University of North Texas',
#   'contact_person': 'Richard Hale/Lee Hughes',
#   'shipping_address': '',
#   'facility_website': ''},
#  'seq_method': {'short_name': 'ILLUMINA',
#   'method_name': 'Illumina Sequencing'},
#  'coverage': None,
#  'finishing_reactions': None,
#  'genome_length': 42890,
#  'gcpercent': '61.2',
#  'end_type': '',
#  'repeat_length': None,
#  'end_notes': '',
#  'overhang_length': 9,
#  'overhang_sequence': 'CGGCAGGGA',
#  'sequencing_notes': "Because this phage was sequenced using a tagmentation library-prep protocol, we can't be 100% sure about the ends and overhang, but there is strong evidence that we have called the correct base 1 and overhang, partly through similarity to related phages.",
#  'duplicate_notes': '',
#  'is_annotated': True,
#  'is_phamerated': True,
#  'num_ORFs': 61,
#  'num_tRNAs': 7,
#  'num_tmRNAs': None,
#  'submitted_dnam_file': None,
#  'submitted_minimal_dnam_file': 'https://phagesdb.org/media/annotation_submission/DNAMasterFiles/Rowa_Minimal_Final.dnam5',
#  'submitted_author_list': None,
#  'submitted_cover_sheet': None,
#  'submitted_annotation_date': '2017-11-25T00:30:31-05:00',
#  'qced_genbank_file': 'https://phagesdb.org/media/annotation_submission/GenBankFiles/Rowa_flat.txt',
#  'qced_genbank_file_date': '2017-11-25T00:30:31-05:00',
#  'isolation_host': {'genus': 'Streptomyces',
#   'species': 'azureus',
#   'strain_name': 'NRRL B-2655',
#   'strain_species': {'id': 23,
#    'genus': 'Streptomyces',
#    'species_name': 'azureus',
#    'species_genus': {'id': 4,
#     'genus_domain': 'Bacteria',
#     'genus_name': 'Streptomyces',
#     'genus_wikipedia': '',
#     'is_actinomycetales': True},
#    'species_wikipedia': ''},
#   'ATCC_ID': '14921',
#   'genbank_accession': '',
#   'strain_information': ''},
#  'verified_hosts': [],
#  'verified_non_hosts': [],
#  'host_species': {'id': 23,
#   'genus': 'Streptomyces',
#   'species_name': 'azureus',
#   'species_genus': {'id': 4,
#    'genus_domain': 'Bacteria',
#    'genus_name': 'Streptomyces',
#    'genus_wikipedia': '',
#    'is_actinomycetales': True},
#   'species_wikipedia': ''},
#  'host_genus': {'id': 4,
#   'genus_domain': 'Bacteria',
#   'genus_name': 'Streptomyces',
#   'genus_wikipedia': '',
#   'is_actinomycetales': True},
#  'in_paper': False,
#  'paper_published_in': None,
#  'in_genbank': True,
#  'genbank_accession': 'MG593803',
#  'refseq_accession': '',
#  'plaque_file': 'https://phagesdb.org/media/plaquePics/Rowa_Plaque.jpg',
#  'em_file': 'https://phagesdb.org/media/emPics/Rowa_EMPic_h1BrzIx.jpg',
#  'digest_file': 'https://phagesdb.org/media/digestPics/Rowa_Digest.jpg',
#  'vdigest_file': None,
#  'fasta_file': 'https://phagesdb.org/media/fastas/Rowa.fasta',
#  'plaque_thumb_file': 'https://phagesdb.org/media/plaquePics/Rowa_Plaque_Thumb.png',
#  'em_thumb_file': 'https://phagesdb.org/media/emPics/Rowa_EMPic_Thumb.jpg',
#  'dnam_file': None,
#  'date_added': '2016-05-25T07:11:42-04:00',
#  'date_modified': '2021-11-26T05:43:11-05:00'}

# %%
import pandas as pd
new_data = []

for x in valid_phages:
    row = []
    row.append(x['phage_name'])
    row.append(x["genome_length"])
    row.append(x["em_file"])
    row.append(x["p_institution"]['institution_code'])
    row.append(x["isolation_host"]["species"])
    new_data.append(row)
    
pd.DataFrame(new_data, columns = ["Phage Name", "Genome Size", "TEM Image", "School", "Species"]).to_csv("phage_images.csv")

# %%
for x in valid_phages:
    print(x["p_institution"]['institution_code'])
# Out:
# UNTD
# UNTD
# WUSL
# WUSL
# WUSL
# UMBC
# UNTD
# UNTD
# LEHI
# UEVN
# UNTD
# UEVN
# UNTD
# UNTD
# UEVN
# UNTD
# UEVN
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UMBC
# UMBC
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# LEHI
# UNTD
# UNTD
# UNTD
# LEHI
# UNTD
# UNTD
# UNTD
# WILK
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# PITT
# WUSL
# WILK
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UNTD
# UNTD
# UNTD
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UMBC
# UNTD
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# WUSL
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
# UNTD
